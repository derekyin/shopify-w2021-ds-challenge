# %% [markdown]
# # Question 1

# %% [markdown]
# ## a)
#
# At first thought, it's probably not a mathematical calculation error, Let's verify this

# %%
import pandas as pd

orders_data_path = '2019 Winter Data Science Intern Challenge Data Set - Sheet1.csv'
orders_df = pd.read_csv(orders_data_path)

orders_df['order_amount'].mean()
# Out:
# 3145.128

# %% [markdown]
# We can see that indeed the mean order value is $3145.13, a high AOV indicates that there exists outlier orders with high `order_amount`.

# %%
import matplotlib.pyplot as plt

plt.scatter(x=orders_df['order_id'], y=orders_df['order_amount'], s=4)
plt.show()

# %% [markdown]
# When we do a scatter plot of `order_amount` vs `order_id`, we can see that the $3145.13 AOV was resulted do to the fact there is a significant amount of outliers with an `order_amount` in the $700,000 range

# %% [markdown]
# ## b)
#
# Instead of AOV, a (set) of metric(s) I would report instead would be `order_amount` percentile values, specficially at:
#
# - p10
# - p50
# - p75
# - p90
# - p95
# - p99

# %% [markdown]
# ## c)

# %%
orders_df['order_amount'].describe(percentiles=[0.1, 0.5, 0.75, 0.9, 0.95, 0.99])
# Out:
# count      5000.000000
# mean       3145.128000
# std       41282.539349
# min          90.000000
# 10%         133.000000
# 50%         284.000000
# 75%         390.000000
# 90%         531.000000
# 95%         640.000000
# 99%       25725.000000
# max      704000.000000
# Name: order_amount, dtype: float64

# %% [markdown]
# # Question 2

# %% [markdown]
# ### a)
#
# ```sql
# SELECT COUNT(OrderID)
# FROM Orders
# LEFT JOIN Shippers ON Orders.ShipperID = Shippers.ShipperID
# WHERE Shippers.ShipperName = 'Speedy Express'
# ```
#
# `= 54`

# %% [markdown]
# ### b)
#
# ```sql
# SELECT LastName
# FROM Employees
# LEFT JOIN Orders
# ON Employees.EmployeeID = Orders.EmployeeID
# GROUP BY Orders.EmployeeID
# ORDER BY COUNT(*) DESC
# LIMIT 1
# ```
#
# `= Peacock`

# %% [markdown]
# ## c)
#
# ```sql
# SELECT ProductName
# FROM Products
# LEFT JOIN OrderDetails
# ON Products.ProductID = OrderDetails.ProductID
# LEFT JOIN Orders
# ON OrderDetails.OrderID = Orders.OrderID
# LEFT JOIN Customers
# ON Orders.CustomerID = Customers.CustomerID
# WHERE Country = 'Germany'
# GROUP BY OrderDetails.ProductID
# ORDER BY COUNT(*) DESC
# LIMIT 1
# ```
#
# `= Gorgonzola Telino`
